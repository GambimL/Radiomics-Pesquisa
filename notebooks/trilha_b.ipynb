# %% [markdown]
# # Tarefa 8b — Trilha B: Classificadores sem Seleção de Features (K-Fold)
#
# Trilha B do pipeline: treinamento com **todas as features** radiômicas (sem seleção prévia).
# Executa as tarefas 3, 4 e 5 do pipeline de experimentos:
#
# - **Tarefa 3**: Rodar todos os 23 modelos × 3 datasets usando 5-fold estratificado, armazenar métricas por fold
# - **Tarefa 4**: Calcular média e desvio-padrão das métricas dos folds por configuração
# - **Tarefa 5**: Selecionar os melhores modelos (top 5 por AUC médio)
#
# **Trilha B** usa apenas `StandardScaler` antes do classificador — nenhuma redução de dimensionalidade aplicada.

# %% [markdown]
# ## Env Configuration
#
# Importações, caminhos, parâmetros globais e configuração do experimento.

# %%
import os
import sys
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings('ignore', category=ConvergenceWarning)
warnings.filterwarnings('ignore', category=UserWarning)

# Paths
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
DATA_DIR     = os.path.join(PROJECT_ROOT, 'data', 'images', 'datasets')
MODULES_DIR  = os.path.join(PROJECT_ROOT, 'modules')
OUTPUT_DIR   = os.path.join(PROJECT_ROOT, 'experiments', 'trilha_b')

if MODULES_DIR not in sys.path:
    sys.path.insert(0, MODULES_DIR)

from models import ALL_CLASSIFIERS, build_plain_pipeline
from evaluation import (
    META_COLS, DATASETS, DS_COLORS,
    aggregate_folds, select_top_models,
    plot_metrics_barh, plot_metrics_heatmap, plot_auc_boxplot,
    run_kfold,
)

os.makedirs(OUTPUT_DIR, exist_ok=True)

# Hiperparametros
N_FOLDS = 5    # numero de folds do k-fold estratificado
SEED    = 42
TOP_N   = 1   # top N modelos selecionados na Tarefa 5

plt.rcParams['figure.dpi'] = 110
plt.rcParams['font.size']  = 9

n_classifiers = len(ALL_CLASSIFIERS)
n_datasets    = len(DATASETS)

print(f'PROJECT_ROOT : {PROJECT_ROOT}')
print(f'OUTPUT_DIR   : {OUTPUT_DIR}')
print(f'N_FOLDS      : {N_FOLDS}')
print(f'Classificadores: {n_classifiers}')
print(f'Datasets       : {list(DATASETS.keys())}')
print(f'Configuracoes  : {n_classifiers * n_datasets} ({n_classifiers} modelos x {n_datasets} datasets)')

# %% [markdown]
# ## Functions
#
# Trilha B usa `build_plain_pipeline` de `modules/models.py` (StandardScaler → classificador, sem seleção de features).
# As demais funções reutilizáveis estão em `modules/evaluation.py`.

# %% [markdown]
# ## Process
#
# Pipeline completo da Trilha B:
# 1. Carrega os 3 datasets radiômicos
# 2. Para cada dataset × classificador: executa k-fold com todas as features (Tarefa 3)
# 3. Agrega média e desvio-padrão por configuração (Tarefa 4)
# 4. Seleciona os melhores modelos por AUC médio (Tarefa 5)
# 5. Gera visualizações e salva resultados

# %% [markdown]
# ### 1. Carga dos datasets

# %%
dfs = {}
for ds_name, ds_file in DATASETS.items():
    df = pd.read_csv(os.path.join(DATA_DIR, ds_file))
    dfs[ds_name] = df
    feat_cols = [c for c in df.columns if c not in META_COLS]
    trainval  = df[df['fold'] != -1]
    test      = df[df['fold'] == -1]
    print(f'=== {ds_name} ===')
    print(f'  trainval: {len(trainval)} | test: {len(test)} | features: {len(feat_cols)}')
    print(f'  Benigno={int((trainval["target"]==0).sum())} | Maligno={int((trainval["target"]==1).sum())}')
    print()
# Out:
# === BW ===
#   trainval: 171 | test: 20 | features: 465
#   Benigno=115 | Maligno=56
#
# === Doppler ===
#   trainval: 171 | test: 20 | features: 465
#   Benigno=115 | Maligno=56
#
# === BW+Doppler ===
#   trainval: 171 | test: 20 | features: 930
#   Benigno=115 | Maligno=56

# %% [markdown]
# ### 2. Tarefa 3 — K-Fold por dataset × classificador
#
# Executa os classificadores × 3 datasets com **todas as features**, cada uma com 5 folds.
# Armazena as métricas individuais de cada fold.

# %%
all_fold_rows = []   # uma linha por fold (Tarefa 3)
all_agg_rows  = []   # uma linha por config (Tarefa 4)

total_configs = len(ALL_CLASSIFIERS) * len(DATASETS)
config_idx    = 0
start_time    = datetime.now()

for ds_name, df in dfs.items():
    feat_cols = [c for c in df.columns if c not in META_COLS]
    trainval  = df[df['fold'] != -1]
    X         = trainval[feat_cols].values.astype(float)
    y         = trainval['target'].values

    for clf_name, clf in ALL_CLASSIFIERS:
        config_idx += 1
        print(f'[{config_idx:2d}/{total_configs}] {ds_name} | {clf_name}...', end=' ', flush=True)

        try:
            pipe         = build_plain_pipeline(clf)
            fold_results = run_kfold(X, y, pipe, n_folds=N_FOLDS, seed=SEED)

            for fr in fold_results:
                all_fold_rows.append({'dataset': ds_name, 'model': clf_name, **fr})

            agg = aggregate_folds(fold_results)
            all_agg_rows.append({'dataset': ds_name, 'model': clf_name, **agg})

            print(f'AUC={agg["auc_mean"]:.3f} +/- {agg["auc_std"]:.3f}')

        except Exception as e:
            print(f'ERRO: {e}')
            all_agg_rows.append({'dataset': ds_name, 'model': clf_name,
                                 'auc_mean': float('nan'), 'error': str(e)})

elapsed = (datetime.now() - start_time).seconds
print(f'\nConcluido em {elapsed}s | {config_idx} configuracoes')

# %% [markdown]
# ### 3. Tarefa 4 — Média e Desvio-Padrão das métricas dos folds

# %%
df_folds = pd.DataFrame(all_fold_rows)
df_agg   = pd.DataFrame(all_agg_rows)

folds_csv = os.path.join(OUTPUT_DIR, 'task3_fold_metrics.csv')
agg_csv   = os.path.join(OUTPUT_DIR, 'task4_aggregated_metrics.csv')
df_folds.to_csv(folds_csv, index=False)
df_agg.to_csv(agg_csv,   index=False)

print(f'Métricas por fold  → {folds_csv}  ({len(df_folds)} linhas)')
print(f'Métricas agregadas → {agg_csv}  ({len(df_agg)} linhas)')
print()

display(
    df_agg[['dataset','model','auc_mean','auc_std','accuracy_mean','sensitivity_mean','specificity_mean']]
    .sort_values('auc_mean', ascending=False)
    .head(10)
    .reset_index(drop=True)
    .style.format({
        'auc_mean':'{:.3f}','auc_std':'{:.3f}',
        'accuracy_mean':'{:.3f}','sensitivity_mean':'{:.3f}','specificity_mean':'{:.3f}'
    })
    .background_gradient(subset=['auc_mean'], cmap='RdYlGn')
)
# Out:
# Métricas por fold  → c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b\task3_fold_metrics.csv  (315 linhas)
# Métricas agregadas → c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b\task4_aggregated_metrics.csv  (66 linhas)
# <style type="text/css">
# #T_156b8_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_156b8_row1_col2 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_156b8_row2_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_156b8_row3_col2 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_156b8_row4_col2 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_156b8_row5_col2 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_156b8_row6_col2 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_156b8_row7_col2 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_156b8_row8_col2, #T_156b8_row9_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_156b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_156b8_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_156b8_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_156b8_level0_col2" class="col_heading level0 col2" >auc_mean</th>
#       <th id="T_156b8_level0_col3" class="col_heading level0 col3" >auc_std</th>
#       <th id="T_156b8_level0_col4" class="col_heading level0 col4" >accuracy_mean</th>
#       <th id="T_156b8_level0_col5" class="col_heading level0 col5" >sensitivity_mean</th>
#       <th id="T_156b8_level0_col6" class="col_heading level0 col6" >specificity_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_156b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_156b8_row0_col0" class="data row0 col0" >Doppler</td>
#       <td id="T_156b8_row0_col1" class="data row0 col1" >Medium Gaussian SVM</td>
#       <td id="T_156b8_row0_col2" class="data row0 col2" >0.825</td>
#       <td id="T_156b8_row0_col3" class="data row0 col3" >0.049</td>
#       <td id="T_156b8_row0_col4" class="data row0 col4" >0.784</td>
#       <td id="T_156b8_row0_col5" class="data row0 col5" >0.520</td>
#       <td id="T_156b8_row0_col6" class="data row0 col6" >0.913</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_156b8_row1_col0" class="data row1 col0" >Doppler</td>
#       <td id="T_156b8_row1_col1" class="data row1 col1" >Coarse KNN</td>
#       <td id="T_156b8_row1_col2" class="data row1 col2" >0.815</td>
#       <td id="T_156b8_row1_col3" class="data row1 col3" >0.083</td>
#       <td id="T_156b8_row1_col4" class="data row1 col4" >0.673</td>
#       <td id="T_156b8_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_156b8_row1_col6" class="data row1 col6" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_156b8_row2_col0" class="data row2 col0" >BW+Doppler</td>
#       <td id="T_156b8_row2_col1" class="data row2 col1" >Medium Gaussian SVM</td>
#       <td id="T_156b8_row2_col2" class="data row2 col2" >0.815</td>
#       <td id="T_156b8_row2_col3" class="data row2 col3" >0.055</td>
#       <td id="T_156b8_row2_col4" class="data row2 col4" >0.778</td>
#       <td id="T_156b8_row2_col5" class="data row2 col5" >0.483</td>
#       <td id="T_156b8_row2_col6" class="data row2 col6" >0.922</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_156b8_row3_col0" class="data row3 col0" >Doppler</td>
#       <td id="T_156b8_row3_col1" class="data row3 col1" >Weighted KNN</td>
#       <td id="T_156b8_row3_col2" class="data row3 col2" >0.806</td>
#       <td id="T_156b8_row3_col3" class="data row3 col3" >0.063</td>
#       <td id="T_156b8_row3_col4" class="data row3 col4" >0.719</td>
#       <td id="T_156b8_row3_col5" class="data row3 col5" >0.573</td>
#       <td id="T_156b8_row3_col6" class="data row3 col6" >0.791</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_156b8_row4_col0" class="data row4 col0" >BW</td>
#       <td id="T_156b8_row4_col1" class="data row4 col1" >Medium Gaussian SVM</td>
#       <td id="T_156b8_row4_col2" class="data row4 col2" >0.798</td>
#       <td id="T_156b8_row4_col3" class="data row4 col3" >0.062</td>
#       <td id="T_156b8_row4_col4" class="data row4 col4" >0.778</td>
#       <td id="T_156b8_row4_col5" class="data row4 col5" >0.483</td>
#       <td id="T_156b8_row4_col6" class="data row4 col6" >0.922</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_156b8_row5_col0" class="data row5 col0" >Doppler</td>
#       <td id="T_156b8_row5_col1" class="data row5 col1" >Subspace KNN</td>
#       <td id="T_156b8_row5_col2" class="data row5 col2" >0.796</td>
#       <td id="T_156b8_row5_col3" class="data row5 col3" >0.083</td>
#       <td id="T_156b8_row5_col4" class="data row5 col4" >0.749</td>
#       <td id="T_156b8_row5_col5" class="data row5 col5" >0.591</td>
#       <td id="T_156b8_row5_col6" class="data row5 col6" >0.826</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_156b8_row6_col0" class="data row6 col0" >Doppler</td>
#       <td id="T_156b8_row6_col1" class="data row6 col1" >Coarse Gaussian SVM</td>
#       <td id="T_156b8_row6_col2" class="data row6 col2" >0.792</td>
#       <td id="T_156b8_row6_col3" class="data row6 col3" >0.087</td>
#       <td id="T_156b8_row6_col4" class="data row6 col4" >0.732</td>
#       <td id="T_156b8_row6_col5" class="data row6 col5" >0.395</td>
#       <td id="T_156b8_row6_col6" class="data row6 col6" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_156b8_row7_col0" class="data row7 col0" >Doppler</td>
#       <td id="T_156b8_row7_col1" class="data row7 col1" >Cosine KNN</td>
#       <td id="T_156b8_row7_col2" class="data row7 col2" >0.788</td>
#       <td id="T_156b8_row7_col3" class="data row7 col3" >0.058</td>
#       <td id="T_156b8_row7_col4" class="data row7 col4" >0.743</td>
#       <td id="T_156b8_row7_col5" class="data row7 col5" >0.626</td>
#       <td id="T_156b8_row7_col6" class="data row7 col6" >0.800</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_156b8_row8_col0" class="data row8 col0" >BW+Doppler</td>
#       <td id="T_156b8_row8_col1" class="data row8 col1" >Weighted KNN</td>
#       <td id="T_156b8_row8_col2" class="data row8 col2" >0.787</td>
#       <td id="T_156b8_row8_col3" class="data row8 col3" >0.071</td>
#       <td id="T_156b8_row8_col4" class="data row8 col4" >0.761</td>
#       <td id="T_156b8_row8_col5" class="data row8 col5" >0.521</td>
#       <td id="T_156b8_row8_col6" class="data row8 col6" >0.878</td>
#     </tr>
#     <tr>
#       <th id="T_156b8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_156b8_row9_col0" class="data row9 col0" >Doppler</td>
#       <td id="T_156b8_row9_col1" class="data row9 col1" >Medium KNN</td>
#       <td id="T_156b8_row9_col2" class="data row9 col2" >0.787</td>
#       <td id="T_156b8_row9_col3" class="data row9 col3" >0.067</td>
#       <td id="T_156b8_row9_col4" class="data row9 col4" >0.708</td>
#       <td id="T_156b8_row9_col5" class="data row9 col5" >0.627</td>
#       <td id="T_156b8_row9_col6" class="data row9 col6" >0.748</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. Tarefa 5 — Seleção dos melhores modelos
#
# Seleciona os **top N** por AUC médio em cada dataset.

# %%
df_top  = select_top_models(df_agg, top_n=TOP_N)
top_csv = os.path.join(OUTPUT_DIR, 'task5_top_models.csv')
df_top.to_csv(top_csv, index=False)

print(f'Top {TOP_N} por dataset → {top_csv}')
print()

for ds_name in DATASETS:
    sub = df_top[df_top['dataset'] == ds_name]
    print(f'--- {ds_name} ---')
    for _, row in sub.iterrows():
        print(f'  #{int(row["rank"])} {row["model"]:<35}  AUC={row["auc_mean"]:.3f} ± {row["auc_std"]:.3f}  '
              f'Acc={row["accuracy_mean"]:.3f}  Sens={row["sensitivity_mean"]:.3f}  Spec={row["specificity_mean"]:.3f}')
    print()
# Out:
# Top 1 por dataset → c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b\task5_top_models.csv
#
# --- BW ---
#   #1 Medium Gaussian SVM                  AUC=0.798 ± 0.062  Acc=0.778  Sens=0.483  Spec=0.922
#
# --- Doppler ---
#   #1 Medium Gaussian SVM                  AUC=0.825 ± 0.049  Acc=0.784  Sens=0.520  Spec=0.913
#
# --- BW+Doppler ---
#   #1 Medium Gaussian SVM                  AUC=0.815 ± 0.055  Acc=0.778  Sens=0.483  Spec=0.922

# %% [markdown]
# ### 5. Visualização — AUC médio por modelo e dataset

# %%
fig, axes = plt.subplots(1, 3, figsize=(22, 9))
fig.suptitle(f'Trilha B — AUC médio (todas as features, {N_FOLDS}-fold)',
             fontsize=14, fontweight='bold')

for ax, ds_name in zip(axes, DATASETS.keys()):
    plot_metrics_barh(df_agg, ds_name, ax, metric='auc_mean')

plt.tight_layout()
out_png = os.path.join(OUTPUT_DIR, 'task5_auc_barh.png')
plt.savefig(out_png, dpi=120, bbox_inches='tight')
plt.show()
print(f'Salvo: {out_png}')
# Out:
# Salvo: c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b\task5_auc_barh.png

# %% [markdown]
# ### 6. Visualização — Heatmap de métricas (top modelos)

# %%
plot_metrics_heatmap(
    df_top, TOP_N,
    output_path=os.path.join(OUTPUT_DIR, 'task5_metrics_heatmap.png'),
    title=f'Trilha B — Heatmap de Métricas (top {TOP_N} por dataset)',
)
# Out:
# Salvo: c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b\task5_metrics_heatmap.png

# %% [markdown]
# ### 7. Visualização — Boxplot de AUC por fold (top modelos)

# %%
plot_auc_boxplot(
    df_folds, df_top, TOP_N,
    output_path=os.path.join(OUTPUT_DIR, 'task5_auc_boxplot.png'),
    title=f'Trilha B — Distribuição AUC por fold (top {TOP_N} por dataset)',
)
# Out:
# Salvo: c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b\task5_auc_boxplot.png

# %% [markdown]
# ### 8. Sumário final

# %%
print('=' * 70)
print(f'TRILHA B — SUMÁRIO FINAL  (todas as features, {N_FOLDS}-fold CV)')
print('=' * 70)
print()

for ds_name in DATASETS:
    sub = df_top[df_top['dataset'] == ds_name]
    print(f'Dataset: {ds_name}')
    print(f"  {'#':<4} {'Modelo':<35} {'AUC':>8} {'Acc':>7} {'Sens':>7} {'Spec':>7} {'F1':>7}")
    print(f"  {'-'*4} {'-'*35} {'-'*8} {'-'*7} {'-'*7} {'-'*7} {'-'*7}")
    for _, row in sub.iterrows():
        print(f"  #{int(row['rank']):<3} {row['model']:<35} "
              f"{row['auc_mean']:>6.3f}±{row['auc_std']:.2f}  "
              f"{row['accuracy_mean']:>6.3f}  "
              f"{row['sensitivity_mean']:>6.3f}  "
              f"{row['specificity_mean']:>6.3f}  "
              f"{row['f1_mean']:>6.3f}")
    print()

print(f'Arquivos salvos em: {OUTPUT_DIR}')
for f in sorted(os.listdir(OUTPUT_DIR)):
    size_kb = os.path.getsize(os.path.join(OUTPUT_DIR, f)) // 1024
    print(f'  {f:<45} {size_kb} KB')
# Out:
# ======================================================================
# TRILHA B — SUMÁRIO FINAL  (todas as features, 5-fold CV)
# ======================================================================
#
# Dataset: BW
#   #    Modelo                                   AUC     Acc    Sens    Spec      F1
#   ---- ----------------------------------- -------- ------- ------- ------- -------
#   #1   Medium Gaussian SVM                  0.798±0.06   0.778   0.483   0.922   0.585
#
# Dataset: Doppler
#   #    Modelo                                   AUC     Acc    Sens    Spec      F1
#   ---- ----------------------------------- -------- ------- ------- ------- -------
#   #1   Medium Gaussian SVM                  0.825±0.05   0.784   0.520   0.913   0.607
#
# Dataset: BW+Doppler
#   #    Modelo                                   AUC     Acc    Sens    Spec      F1
#   ---- ----------------------------------- -------- ------- ------- ------- -------
#   #1   Medium Gaussian SVM                  0.815±0.06   0.778   0.483   0.922   0.576
#
# Arquivos salvos em: c:\Users\LUCAS E GABRIEL\Documents\TCC-PROJECT\experiments\trilha_b
#   task11_accuracy_by_tumor.csv                  1 KB
#   task11_accuracy_by_tumor.png                  82 KB
#   task11_heatmap_model_tumor.png                89 KB
#   task11_prob_by_tumor.png                      66 KB
#   task11_test_predictions.csv                   15 KB
#   task3_fold_metrics.csv                        40 KB
#   task4_aggregated_metrics.csv                  16 KB
#   task5_auc_barh.png                            114 KB
#   task5_auc_boxplot.png                         33 KB
#   task5_metrics_heatmap.png                     51 KB
#   task5_top_models.csv                          0 KB
